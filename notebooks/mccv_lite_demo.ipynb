# %% [markdown]
# ## MCCV Lite Demo Notebook
#
# This notebook demonstrates the **end-to-end MCCV prototype** using the **lite (pure-Python)** implementation:
#
# - Generate **multi-level synthetic data** (beneficiary → diagnosis → multi-modality evidence)
# - Score **clinical coherence** (0 to 1)
# - Compare **fraud vs. non-fraud** cases (ground truth from the generator)
# - Produce a **human-readable audit report** for a flagged case
#
# > Note: This uses `mccv.lite` so it runs even when `numpy` / `pandas` are unavailable or unstable.

# %%
import os
import sys
from statistics import mean

# Ensure we can import the local package
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from mccv.lite.synthetic_generator import MedicareSyntheticGeneratorLite, HCC_DEFINITIONS_LITE
from mccv.lite.knowledge_graph import ClinicalKnowledgeGraphLite
from mccv.lite.rule_based_scorer import RuleBasedCoherenceScorerLite
from mccv.lite.audit_report import AuditReportGeneratorLite

print("Imports OK")
# Out:
# Imports OK

# %%
# 1) Generate synthetic data (multi-level)
#
# For *very large* synthetic datasets, use streaming generation to disk:
#   gen.generate_to_disk("./outputs/synth_big", keep_in_memory=False)
#
# This notebook keeps a moderate dataset in memory so we can inspect cases.

N_BENEFICIARIES = 5_000
FRAUD_RATE = 0.18
SEED = 42

# Optional: generate a very large dataset to disk (do NOT keep in memory)
GENERATE_LARGE_TO_DISK = False
LARGE_N = 200_000
LARGE_OUTDIR = os.path.join(PROJECT_ROOT, "outputs", "synthetic_big")

if GENERATE_LARGE_TO_DISK:
    gen_big = MedicareSyntheticGeneratorLite(n_beneficiaries=LARGE_N, fraud_rate=FRAUD_RATE, seed=SEED)
    gen_big.generate_to_disk(LARGE_OUTDIR, keep_in_memory=False, progress_every=10_000)
    print("Wrote large synthetic dataset to:", LARGE_OUTDIR)

# In-memory demo dataset
gen = MedicareSyntheticGeneratorLite(n_beneficiaries=N_BENEFICIARIES, fraud_rate=FRAUD_RATE, seed=SEED)
data = gen.generate()

meta = (data.get("meta") or [{}])[0]
print("Measurement window:", meta.get("measurement_start_date"), "→", meta.get("measurement_end_date"))
print("Tables:", sorted(data.keys()))
print("Beneficiaries:", len(data["beneficiaries"]))
print("Diagnosis records:", len(data["diagnosis_records"]))
print("Pharmacy claims:", len(data["pharmacy_claims"]))
print("Lab claims:", len(data["lab_claims"]))
print("Specialist visits:", len(data["specialist_visits"]))
print("Procedure claims:", len(data["procedure_claims"]))
print("HRA records:", len(data["hra_records"]))
print("Labels:", len(data["labels"]))
# Out:
# Measurement window: 2023-01-01 → 2024-12-31
# Tables: ['beneficiaries', 'diagnosis_records', 'hra_records', 'lab_claims', 'labels', 'meta', 'pharmacy_claims', 'procedure_claims', 'specialist_visits']
# Beneficiaries: 5000
# Diagnosis records: 8707
# Pharmacy claims: 120196
# Lab claims: 48549
# Specialist visits: 35054
# Procedure claims: 32592
# HRA records: 8707
# Labels: 8707

# %%
data
# Out:
# {'meta': [{'measurement_start_date': '2023-01-01',
#    'measurement_end_date': '2024-12-31',
#    'seed': 42}],
#  'beneficiaries': [{'beneficiary_id': 'BENE_1BD834F24C',
#    'age': 71,
#    'sex': 'M',
#    'state': 'TX',
#    'hcc_codes': ['HCC19', 'HCC18'],
#    'is_fraudulent': True,
#    'fraud_type': 'hra_only'},
#   {'beneficiary_id': 'BENE_B8A24B3D02',
#    'age': 70,
#    'sex': 'F',
#    'state': 'NC',
#    'hcc_codes': ['HCC85', 'HCC19', 'HCC18', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_78428FFBCA',
#    'age': 75,
#    'sex': 'M',
#    'state': 'CA',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_7354EFD389',
#    'age': 69,
#    'sex': 'M',
#    'state': 'IL',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_95F1F114CF',
#    'age': 79,
#    'sex': 'F',
#    'state': 'IL',
#    'hcc_codes': ['HCC111', 'HCC19', 'HCC18'],
#    'is_fraudulent': True,
#    'fraud_type': 'coding_lag'},
#   {'beneficiary_id': 'BENE_9FF3CAA892',
#    'age': 73,
#    'sex': 'M',
#    'state': 'OH',
#    'hcc_codes': ['HCC85', 'HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_F0AF6FEE59',
#    'age': 72,
#    'sex': 'F',
#    'state': 'MI',
#    'hcc_codes': ['HCC85', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_8C9581D6F6',
#    'age': 71,
#    'sex': 'M',
#    'state': 'TX',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_4BC34470E8',
#    'age': 81,
#    'sex': 'M',
#    'state': 'CA',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': True,
#    'fraud_type': 'upcoding'},
#   {'beneficiary_id': 'BENE_840474763E',
#    'age': 70,
#    'sex': 'F',
#    'state': 'GA',
#    'hcc_codes': ['HCC19', 'HCC111', 'HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_7E79BCC9C5',
#    'age': 78,
#    'sex': 'F',
#    'state': 'MD',
#    'hcc_codes': ['HCC19', 'HCC111', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_300D1991FC',
#    'age': 65,
#    'sex': 'M',
#    'state': 'IL',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_696F446002',
#    'age': 79,
#    'sex': 'F',
#    'state': 'OH',
#    'hcc_codes': ['HCC85', 'HCC18'],
#    'is_fraudulent': True,
#    'fraud_type': 'coding_lag'},
#   {'beneficiary_id': 'BENE_BD825F645B',
#    'age': 65,
#    'sex': 'F',
#    'state': 'CA',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_8BAF8711C2',
#    'age': 73,
#    'sex': 'M',
#    'state': 'TX',
#    'hcc_codes': ['HCC111', 'HCC19', 'HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_7C1D2316D0',
#    'age': 80,
#    'sex': 'M',
#    'state': 'FL',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_D579ADE530',
#    'age': 66,
#    'sex': 'M',
#    'state': 'TX',
#    'hcc_codes': ['HCC111', 'HCC19', 'HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_EA41C65C2E',
#    'age': 65,
#    'sex': 'M',
#    'state': 'MO',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_AE87A5F4F4',
#    'age': 65,
#    'sex': 'M',
#    'state': 'NJ',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': True,
#    'fraud_type': 'hra_only'},
#   {'beneficiary_id': 'BENE_F6A761E1EB',
#    'age': 65,
#    'sex': 'M',
#    'state': 'NY',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_724F955794',
#    'age': 86,
#    'sex': 'F',
#    'state': 'MI',
#    'hcc_codes': ['HCC85', 'HCC19'],
#    'is_fraudulent': True,
#    'fraud_type': 'upcoding'},
#   {'beneficiary_id': 'BENE_660D12CFDB',
#    'age': 71,
#    'sex': 'F',
#    'state': 'VA',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_5C1FB5930A',
#    'age': 72,
#    'sex': 'M',
#    'state': 'FL',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_758B99D531',
#    'age': 75,
#    'sex': 'M',
#    'state': 'MO',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_5E0716E79F',
#    'age': 78,
#    'sex': 'F',
#    'state': 'NY',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': True,
#    'fraud_type': 'coding_lag'},
#   {'beneficiary_id': 'BENE_C7F6065904',
#    'age': 66,
#    'sex': 'F',
#    'state': 'PA',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_956B57CAED',
#    'age': 71,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC19', 'HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_72F9C2DA06',
#    'age': 79,
#    'sex': 'F',
#    'state': 'TN',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_3093163A0B',
#    'age': 66,
#    'sex': 'F',
#    'state': 'IL',
#    'hcc_codes': ['HCC111', 'HCC18', 'HCC85', 'HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_FD654FD0A4',
#    'age': 76,
#    'sex': 'M',
#    'state': 'CA',
#    'hcc_codes': ['HCC111', 'HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_050089ED07',
#    'age': 83,
#    'sex': 'F',
#    'state': 'NY',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_F7324FE7FB',
#    'age': 81,
#    'sex': 'M',
#    'state': 'NY',
#    'hcc_codes': ['HCC111', 'HCC19', 'HCC18'],
#    'is_fraudulent': True,
#    'fraud_type': 'upcoding'},
#   {'beneficiary_id': 'BENE_65B5FF9863',
#    'age': 84,
#    'sex': 'F',
#    'state': 'MA',
#    'hcc_codes': ['HCC111', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_96FCE0AB43',
#    'age': 72,
#    'sex': 'M',
#    'state': 'MI',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_31A006B2D6',
#    'age': 67,
#    'sex': 'M',
#    'state': 'NC',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_36AB1A1FBA',
#    'age': 65,
#    'sex': 'M',
#    'state': 'NY',
#    'hcc_codes': ['HCC19', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_F9C7BED033',
#    'age': 65,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_34E5F285BD',
#    'age': 79,
#    'sex': 'F',
#    'state': 'TX',
#    'hcc_codes': ['HCC19', 'HCC111', 'HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_36C60A3D11',
#    'age': 89,
#    'sex': 'M',
#    'state': 'NC',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_60EA3A98D6',
#    'age': 65,
#    'sex': 'F',
#    'state': 'TX',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_FEC74E8EC2',
#    'age': 73,
#    'sex': 'F',
#    'state': 'IL',
#    'hcc_codes': ['HCC18', 'HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_C5041C9078',
#    'age': 65,
#    'sex': 'M',
#    'state': 'FL',
#    'hcc_codes': ['HCC19', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_0BE25863D9',
#    'age': 95,
#    'sex': 'F',
#    'state': 'AZ',
#    'hcc_codes': ['HCC111', 'HCC19', 'HCC85', 'HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_0816D26EF2',
#    'age': 75,
#    'sex': 'M',
#    'state': 'CA',
#    'hcc_codes': ['HCC18', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_E0327E5C93',
#    'age': 89,
#    'sex': 'M',
#    'state': 'PA',
#    'hcc_codes': ['HCC19', 'HCC111', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_7B352F59DF',
#    'age': 65,
#    'sex': 'M',
#    'state': 'VA',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_BD47A5B92C',
#    'age': 73,
#    'sex': 'F',
#    'state': 'IL',
#    'hcc_codes': ['HCC85', 'HCC18', 'HCC19', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_1879B85D8A',
#    'age': 67,
#    'sex': 'M',
#    'state': 'MA',
#    'hcc_codes': ['HCC85', 'HCC19'],
#    'is_fraudulent': True,
#    'fraud_type': 'upcoding'},
#   {'beneficiary_id': 'BENE_38701046B2',
#    'age': 66,
#    'sex': 'F',
#    'state': 'NJ',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_4B83747177',
#    'age': 75,
#    'sex': 'M',
#    'state': 'FL',
#    'hcc_codes': ['HCC111', 'HCC18', 'HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_907BF55D9D',
#    'age': 86,
#    'sex': 'M',
#    'state': 'IL',
#    'hcc_codes': ['HCC19', 'HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_73D2AB5EDE',
#    'age': 72,
#    'sex': 'M',
#    'state': 'TX',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_0B2CE2D6CB',
#    'age': 65,
#    'sex': 'M',
#    'state': 'TX',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_CE65582C68',
#    'age': 83,
#    'sex': 'M',
#    'state': 'GA',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_14167D4EBD',
#    'age': 75,
#    'sex': 'F',
#    'state': 'CA',
#    'hcc_codes': ['HCC19', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_E088B95C38',
#    'age': 94,
#    'sex': 'M',
#    'state': 'NC',
#    'hcc_codes': ['HCC18', 'HCC85', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_02A0925549',
#    'age': 73,
#    'sex': 'F',
#    'state': 'OH',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_6950028D8A',
#    'age': 77,
#    'sex': 'F',
#    'state': 'VA',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_98743E42A6',
#    'age': 74,
#    'sex': 'M',
#    'state': 'NY',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': True,
#    'fraud_type': 'upcoding'},
#   {'beneficiary_id': 'BENE_69360D4CA1',
#    'age': 66,
#    'sex': 'M',
#    'state': 'PA',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_7868497208',
#    'age': 70,
#    'sex': 'F',
#    'state': 'CA',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_1CEA3A7AEB',
#    'age': 65,
#    'sex': 'M',
#    'state': 'FL',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_85D1A62059',
#    'age': 77,
#    'sex': 'M',
#    'state': 'PA',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_91AC9E0B4D',
#    'age': 66,
#    'sex': 'M',
#    'state': 'FL',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_05EDD1FB83',
#    'age': 72,
#    'sex': 'M',
#    'state': 'MA',
#    'hcc_codes': ['HCC85', 'HCC19', 'HCC18', 'HCC111'],
#    'is_fraudulent': True,
#    'fraud_type': 'upcoding'},
#   {'beneficiary_id': 'BENE_DE68FD10FE',
#    'age': 95,
#    'sex': 'F',
#    'state': 'CA',
#    'hcc_codes': ['HCC19', 'HCC85', 'HCC18', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_F214F83EA9',
#    'age': 91,
#    'sex': 'F',
#    'state': 'IN',
#    'hcc_codes': ['HCC111', 'HCC19', 'HCC18', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_F70BE4E52B',
#    'age': 72,
#    'sex': 'F',
#    'state': 'TX',
#    'hcc_codes': ['HCC85', 'HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_3C8E36B670',
#    'age': 65,
#    'sex': 'M',
#    'state': 'CA',
#    'hcc_codes': ['HCC85', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_908112501F',
#    'age': 73,
#    'sex': 'M',
#    'state': 'WI',
#    'hcc_codes': ['HCC18', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_CABBD73B20',
#    'age': 70,
#    'sex': 'F',
#    'state': 'NY',
#    'hcc_codes': ['HCC111', 'HCC18', 'HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_3A4AE6DAB8',
#    'age': 89,
#    'sex': 'F',
#    'state': 'WI',
#    'hcc_codes': ['HCC85', 'HCC19', 'HCC111', 'HCC18'],
#    'is_fraudulent': True,
#    'fraud_type': 'upcoding'},
#   {'beneficiary_id': 'BENE_0D8315E730',
#    'age': 65,
#    'sex': 'M',
#    'state': 'FL',
#    'hcc_codes': ['HCC85', 'HCC19', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_13FD7F7BDE',
#    'age': 67,
#    'sex': 'F',
#    'state': 'OH',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_FA3B551B90',
#    'age': 65,
#    'sex': 'M',
#    'state': 'OH',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': True,
#    'fraud_type': 'upcoding'},
#   {'beneficiary_id': 'BENE_1EF4DBC3E9',
#    'age': 68,
#    'sex': 'F',
#    'state': 'MA',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_5EF557B6AC',
#    'age': 86,
#    'sex': 'M',
#    'state': 'TX',
#    'hcc_codes': ['HCC19', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_195E1A870A',
#    'age': 93,
#    'sex': 'F',
#    'state': 'NC',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': True,
#    'fraud_type': 'upcoding'},
#   {'beneficiary_id': 'BENE_52D562AC03',
#    'age': 72,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_4593B06026',
#    'age': 77,
#    'sex': 'F',
#    'state': 'GA',
#    'hcc_codes': ['HCC111', 'HCC19', 'HCC85', 'HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_B55E8D8957',
#    'age': 65,
#    'sex': 'F',
#    'state': 'IN',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': True,
#    'fraud_type': 'upcoding'},
#   {'beneficiary_id': 'BENE_73DF1F34CE',
#    'age': 78,
#    'sex': 'M',
#    'state': 'MI',
#    'hcc_codes': ['HCC85', 'HCC19', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_B0F7AF01EA',
#    'age': 73,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_A29159334E',
#    'age': 82,
#    'sex': 'M',
#    'state': 'NJ',
#    'hcc_codes': ['HCC111', 'HCC18'],
#    'is_fraudulent': True,
#    'fraud_type': 'paper_diagnosis'},
#   {'beneficiary_id': 'BENE_4337204470',
#    'age': 82,
#    'sex': 'F',
#    'state': 'WI',
#    'hcc_codes': ['HCC18', 'HCC111', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_9EA02BF47D',
#    'age': 77,
#    'sex': 'M',
#    'state': 'TX',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_5D3C1B7C15',
#    'age': 70,
#    'sex': 'F',
#    'state': 'MA',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': True,
#    'fraud_type': 'paper_diagnosis'},
#   {'beneficiary_id': 'BENE_FB539ABC6E',
#    'age': 95,
#    'sex': 'M',
#    'state': 'TX',
#    'hcc_codes': ['HCC19', 'HCC85', 'HCC111', 'HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_B08F03F104',
#    'age': 80,
#    'sex': 'F',
#    'state': 'WI',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_2682483850',
#    'age': 65,
#    'sex': 'F',
#    'state': 'CA',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_910578898A',
#    'age': 75,
#    'sex': 'F',
#    'state': 'MO',
#    'hcc_codes': ['HCC19', 'HCC85', 'HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_EAAD880BE0',
#    'age': 65,
#    'sex': 'M',
#    'state': 'CA',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': True,
#    'fraud_type': 'hra_only'},
#   {'beneficiary_id': 'BENE_C661AB4231',
#    'age': 82,
#    'sex': 'M',
#    'state': 'GA',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_F43C4C351D',
#    'age': 80,
#    'sex': 'F',
#    'state': 'TX',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_C3E8CD3E11',
#    'age': 67,
#    'sex': 'F',
#    'state': 'TN',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_826830D298',
#    'age': 66,
#    'sex': 'F',
#    'state': 'CA',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_D940DAADC4',
#    'age': 65,
#    'sex': 'M',
#    'state': 'VA',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_13B5EB5FE5',
#    'age': 76,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC18', 'HCC19', 'HCC111'],
#    'is_fraudulent': True,
#    'fraud_type': 'hra_only'},
#   {'beneficiary_id': 'BENE_AE38B4FD0A',
#    'age': 71,
#    'sex': 'M',
#    'state': 'CA',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': True,
#    'fraud_type': 'paper_diagnosis'},
#   {'beneficiary_id': 'BENE_DF5254340A',
#    'age': 65,
#    'sex': 'M',
#    'state': 'TN',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_1A8625673F',
#    'age': 82,
#    'sex': 'F',
#    'state': 'OH',
#    'hcc_codes': ['HCC111', 'HCC85'],
#    'is_fraudulent': True,
#    'fraud_type': 'upcoding'},
#   {'beneficiary_id': 'BENE_47F55EE9F7',
#    'age': 65,
#    'sex': 'M',
#    'state': 'CA',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_6654D9CB16',
#    'age': 65,
#    'sex': 'F',
#    'state': 'MA',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_E4FBCC55E7',
#    'age': 92,
#    'sex': 'F',
#    'state': 'TX',
#    'hcc_codes': ['HCC18', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_41BA57DAD8',
#    'age': 72,
#    'sex': 'F',
#    'state': 'TN',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_DDF5D556B5',
#    'age': 77,
#    'sex': 'M',
#    'state': 'GA',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_94235BBCA6',
#    'age': 85,
#    'sex': 'F',
#    'state': 'MD',
#    'hcc_codes': ['HCC18', 'HCC19', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_21625865E9',
#    'age': 91,
#    'sex': 'F',
#    'state': 'MA',
#    'hcc_codes': ['HCC19', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_455579E88F',
#    'age': 88,
#    'sex': 'M',
#    'state': 'IN',
#    'hcc_codes': ['HCC18', 'HCC85', 'HCC19', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_0DDE33C159',
#    'age': 75,
#    'sex': 'F',
#    'state': 'MA',
#    'hcc_codes': ['HCC19', 'HCC111', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_79A1DDE78C',
#    'age': 75,
#    'sex': 'F',
#    'state': 'CA',
#    'hcc_codes': ['HCC18', 'HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_BBE80FF427',
#    'age': 65,
#    'sex': 'F',
#    'state': 'MA',
#    'hcc_codes': ['HCC19', 'HCC18', 'HCC111', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_15A02E9E7F',
#    'age': 75,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': True,
#    'fraud_type': 'coding_lag'},
#   {'beneficiary_id': 'BENE_FEAD7F8A12',
#    'age': 90,
#    'sex': 'F',
#    'state': 'TX',
#    'hcc_codes': ['HCC18', 'HCC111'],
#    'is_fraudulent': True,
#    'fraud_type': 'paper_diagnosis'},
#   {'beneficiary_id': 'BENE_23F5641CE8',
#    'age': 78,
#    'sex': 'M',
#    'state': 'MA',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': True,
#    'fraud_type': 'coding_lag'},
#   {'beneficiary_id': 'BENE_CF360CE0FA',
#    'age': 73,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC18', 'HCC19', 'HCC85', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_0BA9CBC08A',
#    'age': 66,
#    'sex': 'F',
#    'state': 'IL',
#    'hcc_codes': ['HCC18', 'HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_8DA0F6C420',
#    'age': 65,
#    'sex': 'F',
#    'state': 'CA',
#    'hcc_codes': ['HCC19', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_ECF90D0490',
#    'age': 78,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC19', 'HCC85', 'HCC18', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_0CCA22C344',
#    'age': 71,
#    'sex': 'M',
#    'state': 'NY',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_191A967CC5',
#    'age': 71,
#    'sex': 'F',
#    'state': 'IL',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_AFAD100889',
#    'age': 65,
#    'sex': 'M',
#    'state': 'OH',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_80201F9A03',
#    'age': 72,
#    'sex': 'M',
#    'state': 'IN',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_53E20ADB92',
#    'age': 88,
#    'sex': 'F',
#    'state': 'MI',
#    'hcc_codes': ['HCC19', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_098D734158',
#    'age': 71,
#    'sex': 'M',
#    'state': 'CA',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_DA7B8D0865',
#    'age': 65,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_CB92C6835E',
#    'age': 65,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_C6A2344087',
#    'age': 90,
#    'sex': 'M',
#    'state': 'NY',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_D59DEA9874',
#    'age': 65,
#    'sex': 'M',
#    'state': 'NY',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': True,
#    'fraud_type': 'hra_only'},
#   {'beneficiary_id': 'BENE_6EA2C4C1F6',
#    'age': 77,
#    'sex': 'F',
#    'state': 'NC',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_1606F9E359',
#    'age': 83,
#    'sex': 'M',
#    'state': 'IL',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_0FC7E32DC8',
#    'age': 65,
#    'sex': 'M',
#    'state': 'FL',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': True,
#    'fraud_type': 'paper_diagnosis'},
#   {'beneficiary_id': 'BENE_390983142F',
#    'age': 65,
#    'sex': 'F',
#    'state': 'PA',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_F031CF17D1',
#    'age': 78,
#    'sex': 'M',
#    'state': 'TX',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_7BE3764E50',
#    'age': 65,
#    'sex': 'F',
#    'state': 'TX',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': True,
#    'fraud_type': 'coding_lag'},
#   {'beneficiary_id': 'BENE_C57DBAFEB7',
#    'age': 76,
#    'sex': 'M',
#    'state': 'IL',
#    'hcc_codes': ['HCC111', 'HCC18'],
#    'is_fraudulent': True,
#    'fraud_type': 'paper_diagnosis'},
#   {'beneficiary_id': 'BENE_CBEAD8DE26',
#    'age': 66,
#    'sex': 'F',
#    'state': 'NJ',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': True,
#    'fraud_type': 'paper_diagnosis'},
#   {'beneficiary_id': 'BENE_E2422F8CF8',
#    'age': 65,
#    'sex': 'F',
#    'state': 'TX',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_0D65127411',
#    'age': 73,
#    'sex': 'M',
#    'state': 'PA',
#    'hcc_codes': ['HCC19', 'HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_F3E218C229',
#    'age': 74,
#    'sex': 'F',
#    'state': 'CA',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_49BEA5405A',
#    'age': 65,
#    'sex': 'M',
#    'state': 'MI',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_66E7F04665',
#    'age': 79,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC111', 'HCC19'],
#    'is_fraudulent': True,
#    'fraud_type': 'upcoding'},
#   {'beneficiary_id': 'BENE_21625A5003',
#    'age': 71,
#    'sex': 'F',
#    'state': 'VA',
#    'hcc_codes': ['HCC19', 'HCC85', 'HCC111', 'HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_11141C11D4',
#    'age': 71,
#    'sex': 'M',
#    'state': 'NY',
#    'hcc_codes': ['HCC85', 'HCC18', 'HCC19', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_FA9BC6BF61',
#    'age': 83,
#    'sex': 'F',
#    'state': 'CA',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_EA3CD05FCB',
#    'age': 94,
#    'sex': 'M',
#    'state': 'AZ',
#    'hcc_codes': ['HCC19', 'HCC18', 'HCC85'],
#    'is_fraudulent': True,
#    'fraud_type': 'paper_diagnosis'},
#   {'beneficiary_id': 'BENE_F502461665',
#    'age': 65,
#    'sex': 'F',
#    'state': 'WI',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_329BB889DC',
#    'age': 77,
#    'sex': 'F',
#    'state': 'MO',
#    'hcc_codes': ['HCC18', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_688949FF20',
#    'age': 83,
#    'sex': 'F',
#    'state': 'IL',
#    'hcc_codes': ['HCC111', 'HCC85'],
#    'is_fraudulent': True,
#    'fraud_type': 'paper_diagnosis'},
#   {'beneficiary_id': 'BENE_F04E787C87',
#    'age': 65,
#    'sex': 'F',
#    'state': 'IL',
#    'hcc_codes': ['HCC19', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_DF8DF49A39',
#    'age': 85,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC18', 'HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_E9264EABCF',
#    'age': 65,
#    'sex': 'M',
#    'state': 'GA',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_D60DABB7A8',
#    'age': 73,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC18', 'HCC85', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_34D1AE2E24',
#    'age': 65,
#    'sex': 'M',
#    'state': 'FL',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_5A3A13D7D7',
#    'age': 71,
#    'sex': 'F',
#    'state': 'TX',
#    'hcc_codes': ['HCC18', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_0F1BBB8610',
#    'age': 81,
#    'sex': 'M',
#    'state': 'MI',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_20983AFE6D',
#    'age': 71,
#    'sex': 'M',
#    'state': 'IL',
#    'hcc_codes': ['HCC18', 'HCC111', 'HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_DE85641167',
#    'age': 68,
#    'sex': 'M',
#    'state': 'TX',
#    'hcc_codes': ['HCC19', 'HCC85', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_24F03D0CD3',
#    'age': 65,
#    'sex': 'F',
#    'state': 'MI',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_F7E1CFC6AF',
#    'age': 82,
#    'sex': 'F',
#    'state': 'VA',
#    'hcc_codes': ['HCC18', 'HCC85', 'HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_872134C30E',
#    'age': 71,
#    'sex': 'M',
#    'state': 'NJ',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_4654653685',
#    'age': 73,
#    'sex': 'F',
#    'state': 'MO',
#    'hcc_codes': ['HCC19', 'HCC18', 'HCC111'],
#    'is_fraudulent': True,
#    'fraud_type': 'hra_only'},
#   {'beneficiary_id': 'BENE_99D643E2F9',
#    'age': 65,
#    'sex': 'F',
#    'state': 'GA',
#    'hcc_codes': ['HCC18', 'HCC19', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_32AAFB1CCB',
#    'age': 80,
#    'sex': 'M',
#    'state': 'TX',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_2D7F5FF537',
#    'age': 70,
#    'sex': 'M',
#    'state': 'NC',
#    'hcc_codes': ['HCC18', 'HCC85'],
#    'is_fraudulent': True,
#    'fraud_type': 'upcoding'},
#   {'beneficiary_id': 'BENE_8F790097C3',
#    'age': 73,
#    'sex': 'M',
#    'state': 'TX',
#    'hcc_codes': ['HCC18', 'HCC19', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_20C6762AB2',
#    'age': 67,
#    'sex': 'F',
#    'state': 'CA',
#    'hcc_codes': ['HCC19', 'HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_97DDED5D0A',
#    'age': 73,
#    'sex': 'M',
#    'state': 'OH',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_2EDBE93DFF',
#    'age': 86,
#    'sex': 'M',
#    'state': 'PA',
#    'hcc_codes': ['HCC18', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_E44BB25E4B',
#    'age': 74,
#    'sex': 'M',
#    'state': 'NY',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_E02FEA148B',
#    'age': 74,
#    'sex': 'F',
#    'state': 'NY',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_501D5FCEEF',
#    'age': 81,
#    'sex': 'F',
#    'state': 'AZ',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_0D749997A4',
#    'age': 72,
#    'sex': 'M',
#    'state': 'IL',
#    'hcc_codes': ['HCC85', 'HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_4930EB23A5',
#    'age': 76,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC18', 'HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_29992F6BC3',
#    'age': 65,
#    'sex': 'F',
#    'state': 'NJ',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': True,
#    'fraud_type': 'upcoding'},
#   {'beneficiary_id': 'BENE_55A8EFDFA3',
#    'age': 65,
#    'sex': 'F',
#    'state': 'TX',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_3760483F31',
#    'age': 78,
#    'sex': 'M',
#    'state': 'NC',
#    'hcc_codes': ['HCC111', 'HCC18', 'HCC19', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_4D28519AE2',
#    'age': 73,
#    'sex': 'F',
#    'state': 'TX',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_CC37416BD9',
#    'age': 67,
#    'sex': 'M',
#    'state': 'GA',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_5029EA26DE',
#    'age': 65,
#    'sex': 'F',
#    'state': 'CA',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_C1FCA38B2F',
#    'age': 83,
#    'sex': 'M',
#    'state': 'CA',
#    'hcc_codes': ['HCC85', 'HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_33F72CC680',
#    'age': 65,
#    'sex': 'M',
#    'state': 'NC',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_1DC9C8B7F9',
#    'age': 82,
#    'sex': 'F',
#    'state': 'CA',
#    'hcc_codes': ['HCC19', 'HCC18', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_BD7DC29C35',
#    'age': 69,
#    'sex': 'F',
#    'state': 'GA',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_262C128BFF',
#    'age': 86,
#    'sex': 'F',
#    'state': 'GA',
#    'hcc_codes': ['HCC85', 'HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_86821E80FB',
#    'age': 82,
#    'sex': 'M',
#    'state': 'WI',
#    'hcc_codes': ['HCC85', 'HCC19', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_CA4000ED1A',
#    'age': 74,
#    'sex': 'M',
#    'state': 'NY',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_DA4F7C3A77',
#    'age': 65,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_5FDAA2B2DA',
#    'age': 83,
#    'sex': 'M',
#    'state': 'MD',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_98DDD33DF1',
#    'age': 65,
#    'sex': 'F',
#    'state': 'AZ',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': True,
#    'fraud_type': 'paper_diagnosis'},
#   {'beneficiary_id': 'BENE_2C611FFC05',
#    'age': 69,
#    'sex': 'F',
#    'state': 'MD',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_49BBDE3ED8',
#    'age': 65,
#    'sex': 'M',
#    'state': 'WA',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_53E4993ABB',
#    'age': 65,
#    'sex': 'M',
#    'state': 'NJ',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_771DD41559',
#    'age': 69,
#    'sex': 'M',
#    'state': 'MA',
#    'hcc_codes': ['HCC111', 'HCC85', 'HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_4CB7825E18',
#    'age': 74,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_D7066A6451',
#    'age': 68,
#    'sex': 'F',
#    'state': 'GA',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_3E7761106F',
#    'age': 70,
#    'sex': 'F',
#    'state': 'TX',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': True,
#    'fraud_type': 'paper_diagnosis'},
#   {'beneficiary_id': 'BENE_8F6D9FFE5F',
#    'age': 74,
#    'sex': 'M',
#    'state': 'WA',
#    'hcc_codes': ['HCC18', 'HCC19', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_0A50285D1A',
#    'age': 65,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC18', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_4D5857EEF4',
#    'age': 89,
#    'sex': 'M',
#    'state': 'MO',
#    'hcc_codes': ['HCC19', 'HCC18', 'HCC85', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_FE75AA17E6',
#    'age': 86,
#    'sex': 'F',
#    'state': 'VA',
#    'hcc_codes': ['HCC111', 'HCC18', 'HCC19', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_DE401F1D66',
#    'age': 80,
#    'sex': 'F',
#    'state': 'NC',
#    'hcc_codes': ['HCC18', 'HCC19', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_16E3C9470A',
#    'age': 65,
#    'sex': 'M',
#    'state': 'TX',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_4B172E1B21',
#    'age': 73,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_797E2B56EF',
#    'age': 65,
#    'sex': 'F',
#    'state': 'NY',
#    'hcc_codes': ['HCC19', 'HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_53F721C464',
#    'age': 66,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_02A1FB6EFF',
#    'age': 70,
#    'sex': 'M',
#    'state': 'CA',
#    'hcc_codes': ['HCC19', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_D40218D682',
#    'age': 65,
#    'sex': 'M',
#    'state': 'CA',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_9E446E906D',
#    'age': 65,
#    'sex': 'M',
#    'state': 'TX',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_B356A26F68',
#    'age': 68,
#    'sex': 'F',
#    'state': 'NJ',
#    'hcc_codes': ['HCC18', 'HCC19'],
#    'is_fraudulent': True,
#    'fraud_type': 'hra_only'},
#   {'beneficiary_id': 'BENE_93D6BC31BE',
#    'age': 84,
#    'sex': 'M',
#    'state': 'CA',
#    'hcc_codes': ['HCC18', 'HCC85', 'HCC19', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_8B3E3E1DDA',
#    'age': 70,
#    'sex': 'M',
#    'state': 'TX',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': True,
#    'fraud_type': 'hra_only'},
#   {'beneficiary_id': 'BENE_0A179A6731',
#    'age': 73,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_3DD043730C',
#    'age': 74,
#    'sex': 'F',
#    'state': 'OH',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_1144C3409C',
#    'age': 70,
#    'sex': 'F',
#    'state': 'PA',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_16D2CBB669',
#    'age': 67,
#    'sex': 'F',
#    'state': 'OH',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_99B4CB346B',
#    'age': 65,
#    'sex': 'M',
#    'state': 'CA',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': True,
#    'fraud_type': 'paper_diagnosis'},
#   {'beneficiary_id': 'BENE_6023CFF3DA',
#    'age': 74,
#    'sex': 'F',
#    'state': 'PA',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_82D80965F9',
#    'age': 76,
#    'sex': 'M',
#    'state': 'GA',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_8310925BF9',
#    'age': 65,
#    'sex': 'M',
#    'state': 'TX',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_7CE2EDC4CB',
#    'age': 65,
#    'sex': 'F',
#    'state': 'CA',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_0F507F11BA',
#    'age': 69,
#    'sex': 'F',
#    'state': 'GA',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_08331E2D27',
#    'age': 74,
#    'sex': 'F',
#    'state': 'PA',
#    'hcc_codes': ['HCC19', 'HCC18', 'HCC111'],
#    'is_fraudulent': True,
#    'fraud_type': 'coding_lag'},
#   {'beneficiary_id': 'BENE_F62F436588',
#    'age': 65,
#    'sex': 'M',
#    'state': 'MA',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': True,
#    'fraud_type': 'upcoding'},
#   {'beneficiary_id': 'BENE_0BD0016CC0',
#    'age': 81,
#    'sex': 'F',
#    'state': 'GA',
#    'hcc_codes': ['HCC111', 'HCC19', 'HCC18', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_86069205D3',
#    'age': 71,
#    'sex': 'F',
#    'state': 'MO',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_F897C441B3',
#    'age': 74,
#    'sex': 'F',
#    'state': 'TX',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_E5B1E0AB99',
#    'age': 79,
#    'sex': 'M',
#    'state': 'CA',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_214813EF8E',
#    'age': 83,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_677D29DE0C',
#    'age': 72,
#    'sex': 'M',
#    'state': 'MI',
#    'hcc_codes': ['HCC85', 'HCC111', 'HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_9C1E66D668',
#    'age': 69,
#    'sex': 'F',
#    'state': 'IN',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': True,
#    'fraud_type': 'upcoding'},
#   {'beneficiary_id': 'BENE_D28CB4E4F1',
#    'age': 65,
#    'sex': 'F',
#    'state': 'GA',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_2F7B6DE543',
#    'age': 65,
#    'sex': 'M',
#    'state': 'IL',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_36C290A902',
#    'age': 65,
#    'sex': 'F',
#    'state': 'TN',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': True,
#    'fraud_type': 'hra_only'},
#   {'beneficiary_id': 'BENE_6E324944CC',
#    'age': 74,
#    'sex': 'M',
#    'state': 'FL',
#    'hcc_codes': ['HCC111', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_C55976B972',
#    'age': 69,
#    'sex': 'F',
#    'state': 'OH',
#    'hcc_codes': ['HCC111', 'HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_A01F644018',
#    'age': 71,
#    'sex': 'F',
#    'state': 'MI',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_A293F77F4B',
#    'age': 77,
#    'sex': 'F',
#    'state': 'IL',
#    'hcc_codes': ['HCC18', 'HCC19', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_98F6768E8D',
#    'age': 68,
#    'sex': 'M',
#    'state': 'NY',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_16D2F895D7',
#    'age': 72,
#    'sex': 'M',
#    'state': 'FL',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_3A16D63B47',
#    'age': 93,
#    'sex': 'F',
#    'state': 'OH',
#    'hcc_codes': ['HCC19', 'HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_05B2159937',
#    'age': 86,
#    'sex': 'F',
#    'state': 'WI',
#    'hcc_codes': ['HCC18', 'HCC111', 'HCC85', 'HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_A37314EEEC',
#    'age': 68,
#    'sex': 'M',
#    'state': 'VA',
#    'hcc_codes': ['HCC18', 'HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_5D1146F63D',
#    'age': 65,
#    'sex': 'F',
#    'state': 'NC',
#    'hcc_codes': ['HCC18', 'HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_4B57360304',
#    'age': 77,
#    'sex': 'F',
#    'state': 'GA',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': True,
#    'fraud_type': 'upcoding'},
#   {'beneficiary_id': 'BENE_6D1A382F7D',
#    'age': 69,
#    'sex': 'F',
#    'state': 'CA',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_73780D7DD6',
#    'age': 67,
#    'sex': 'F',
#    'state': 'MA',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_E89FBD0209',
#    'age': 79,
#    'sex': 'M',
#    'state': 'MI',
#    'hcc_codes': ['HCC85', 'HCC19', 'HCC111', 'HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_65DE4F0285',
#    'age': 66,
#    'sex': 'F',
#    'state': 'IL',
#    'hcc_codes': ['HCC18', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_300AD2EF51',
#    'age': 95,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC18', 'HCC111', 'HCC19', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_7123EAF18E',
#    'age': 65,
#    'sex': 'M',
#    'state': 'IL',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_34FDCBCCF3',
#    'age': 96,
#    'sex': 'F',
#    'state': 'NC',
#    'hcc_codes': ['HCC18', 'HCC111', 'HCC19', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_6126FAAE41',
#    'age': 65,
#    'sex': 'M',
#    'state': 'NY',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_3585C6C68C',
#    'age': 69,
#    'sex': 'F',
#    'state': 'GA',
#    'hcc_codes': ['HCC18', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_AFDA9B2F3C',
#    'age': 72,
#    'sex': 'F',
#    'state': 'IN',
#    'hcc_codes': ['HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_739F48A748',
#    'age': 65,
#    'sex': 'M',
#    'state': 'MI',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_79CE0D6E17',
#    'age': 91,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC18', 'HCC111', 'HCC19', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_89E5C3E643',
#    'age': 91,
#    'sex': 'M',
#    'state': 'IL',
#    'hcc_codes': ['HCC18', 'HCC19', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_05FE6434E1',
#    'age': 68,
#    'sex': 'F',
#    'state': 'TN',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_5C9BDD94DB',
#    'age': 71,
#    'sex': 'F',
#    'state': 'CA',
#    'hcc_codes': ['HCC18', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_4D723C2211',
#    'age': 78,
#    'sex': 'F',
#    'state': 'IL',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_6AC115AE7A',
#    'age': 65,
#    'sex': 'M',
#    'state': 'AZ',
#    'hcc_codes': ['HCC19', 'HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_10C63E2599',
#    'age': 79,
#    'sex': 'F',
#    'state': 'NY',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_66A9D92E23',
#    'age': 71,
#    'sex': 'F',
#    'state': 'IL',
#    'hcc_codes': ['HCC18', 'HCC85', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_864316C6B9',
#    'age': 87,
#    'sex': 'M',
#    'state': 'WA',
#    'hcc_codes': ['HCC18', 'HCC19', 'HCC111', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_23BE488E63',
#    'age': 65,
#    'sex': 'M',
#    'state': 'IN',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': True,
#    'fraud_type': 'paper_diagnosis'},
#   {'beneficiary_id': 'BENE_0789A91F23',
#    'age': 65,
#    'sex': 'M',
#    'state': 'FL',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_1C5DA2A9B5',
#    'age': 71,
#    'sex': 'F',
#    'state': 'WI',
#    'hcc_codes': ['HCC18'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_813B6CD9D4',
#    'age': 66,
#    'sex': 'F',
#    'state': 'FL',
#    'hcc_codes': ['HCC111', 'HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_773AC3A752',
#    'age': 72,
#    'sex': 'F',
#    'state': 'IL',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_6FA1FBF0FF',
#    'age': 65,
#    'sex': 'M',
#    'state': 'MI',
#    'hcc_codes': ['HCC19', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_4AD7540CB7',
#    'age': 74,
#    'sex': 'F',
#    'state': 'TX',
#    'hcc_codes': ['HCC18', 'HCC85', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_EDCDED1704',
#    'age': 72,
#    'sex': 'F',
#    'state': 'MI',
#    'hcc_codes': ['HCC19', 'HCC85'],
#    'is_fraudulent': True,
#    'fraud_type': 'hra_only'},
#   {'beneficiary_id': 'BENE_35B6D96EE3',
#    'age': 69,
#    'sex': 'F',
#    'state': 'NY',
#    'hcc_codes': ['HCC19'],
#    'is_fraudulent': True,
#    'fraud_type': 'upcoding'},
#   {'beneficiary_id': 'BENE_BD4552CDF9',
#    'age': 65,
#    'sex': 'F',
#    'state': 'PA',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_2E5C7D2F32',
#    'age': 65,
#    'sex': 'M',
#    'state': 'IL',
#    'hcc_codes': ['HCC19', 'HCC111'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_197349748A',
#    'age': 65,
#    'sex': 'F',
#    'state': 'NY',
#    'hcc_codes': ['HCC18', 'HCC19', 'HCC111', 'HCC85'],
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_0AAC044765',
#    'age': 65,
#    'sex': 'F',
#    'state': 'PA',
#    'hcc_codes': ['HCC111'],
#    'is_fraudulent': True,
#    'fraud_type': 'coding_lag'},
# ...
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_7A39C0FA67',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.703,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_7A39C0FA67',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.754,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_A1123F4C13',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.716,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_A1C88FD27A',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.967,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_D18E4E7614',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.033,
#    'is_fraudulent': True,
#    'fraud_type': 'paper_diagnosis'},
#   {'beneficiary_id': 'BENE_D18E4E7614',
#    'hcc_code': 'HCC85',
#    'coherence_score': 0.083,
#    'is_fraudulent': True,
#    'fraud_type': 'paper_diagnosis'},
#   {'beneficiary_id': 'BENE_67D33F1C81',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.838,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_4C1ACA7F4B',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.874,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_4C1ACA7F4B',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.892,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_4C1ACA7F4B',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.895,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_A014262526',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.931,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_C3E6CDBEF6',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.846,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_89298B5ABE',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.783,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_31BCF77B54',
#    'hcc_code': 'HCC85',
#    'coherence_score': 0.955,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_31BCF77B54',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.834,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_31BCF77B54',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.905,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_31BCF77B54',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.728,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_5F154E9D13',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.855,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_5F154E9D13',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.819,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_FF435E1683',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.84,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_DBFDCF6516',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.861,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_DBFDCF6516',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.737,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_1E8EE997FB',
#    'hcc_code': 'HCC85',
#    'coherence_score': 0.93,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_75B8961E8E',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.785,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_024522EFF9',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.004,
#    'is_fraudulent': True,
#    'fraud_type': 'paper_diagnosis'},
#   {'beneficiary_id': 'BENE_5730C31BBA',
#    'hcc_code': 'HCC85',
#    'coherence_score': 0.941,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_5730C31BBA',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.966,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_5730C31BBA',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.819,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_FEC2E27E87',
#    'hcc_code': 'HCC85',
#    'coherence_score': 0.755,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_FEC2E27E87',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.949,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_B2BF29650F',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.821,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_AC5DC5B007',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.032,
#    'is_fraudulent': True,
#    'fraud_type': 'paper_diagnosis'},
#   {'beneficiary_id': 'BENE_B44AAF802F',
#    'hcc_code': 'HCC85',
#    'coherence_score': 0.969,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_520C1079B0',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.171,
#    'is_fraudulent': True,
#    'fraud_type': 'hra_only'},
#   {'beneficiary_id': 'BENE_520C1079B0',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.152,
#    'is_fraudulent': True,
#    'fraud_type': 'hra_only'},
#   {'beneficiary_id': 'BENE_24E5BC6347',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.902,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_10E7BB2E55',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.969,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_042D698259',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.925,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_46433F0496',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.05,
#    'is_fraudulent': True,
#    'fraud_type': 'paper_diagnosis'},
#   {'beneficiary_id': 'BENE_46433F0496',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.028,
#    'is_fraudulent': True,
#    'fraud_type': 'paper_diagnosis'},
#   {'beneficiary_id': 'BENE_53BE6A83DA',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.223,
#    'is_fraudulent': True,
#    'fraud_type': 'hra_only'},
#   {'beneficiary_id': 'BENE_53BE6A83DA',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.194,
#    'is_fraudulent': True,
#    'fraud_type': 'hra_only'},
#   {'beneficiary_id': 'BENE_49008C45F7',
#    'hcc_code': 'HCC85',
#    'coherence_score': 0.383,
#    'is_fraudulent': True,
#    'fraud_type': 'upcoding'},
#   {'beneficiary_id': 'BENE_0F8FEA20FA',
#    'hcc_code': 'HCC85',
#    'coherence_score': 0.857,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_3945B249F6',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.36,
#    'is_fraudulent': True,
#    'fraud_type': 'upcoding'},
#   {'beneficiary_id': 'BENE_E0546BE3BA',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.838,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_E0546BE3BA',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.974,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_D650ADCEE6',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.708,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_D650ADCEE6',
#    'hcc_code': 'HCC85',
#    'coherence_score': 0.976,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_1BE1AE50D5',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.712,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_A93967A240',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.758,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_98352EED74',
#    'hcc_code': 'HCC85',
#    'coherence_score': 0.85,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_98352EED74',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.714,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_98352EED74',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.747,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_98352EED74',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.747,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_B7DD83BC71',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.711,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_D9FF39A509',
#    'hcc_code': 'HCC85',
#    'coherence_score': 0.974,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_71A86110C8',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.719,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_71A86110C8',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.967,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_CA99DCCECB',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.961,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_CA99DCCECB',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.897,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_2EE4BE05EB',
#    'hcc_code': 'HCC85',
#    'coherence_score': 0.911,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_5742EBD01C',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.72,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_6A15B2A04A',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.75,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_1DA86E3515',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.747,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_A8CC1B1A53',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.956,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_F1292541F6',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.873,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_6223F9EAC2',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.919,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_6223F9EAC2',
#    'hcc_code': 'HCC85',
#    'coherence_score': 0.738,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_6223F9EAC2',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.937,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_D6E9008845',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.852,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_D6E9008845',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.796,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_E6FE88C678',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.843,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_E6FE88C678',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.902,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_E6FE88C678',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.721,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_E6FE88C678',
#    'hcc_code': 'HCC85',
#    'coherence_score': 0.763,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_050367810F',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.007,
#    'is_fraudulent': True,
#    'fraud_type': 'coding_lag'},
#   {'beneficiary_id': 'BENE_050367810F',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.016,
#    'is_fraudulent': True,
#    'fraud_type': 'coding_lag'},
#   {'beneficiary_id': 'BENE_843DC9834F',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.934,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_711AE4C6A2',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.202,
#    'is_fraudulent': True,
#    'fraud_type': 'coding_lag'},
#   {'beneficiary_id': 'BENE_711AE4C6A2',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.084,
#    'is_fraudulent': True,
#    'fraud_type': 'coding_lag'},
#   {'beneficiary_id': 'BENE_711AE4C6A2',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.202,
#    'is_fraudulent': True,
#    'fraud_type': 'coding_lag'},
#   {'beneficiary_id': 'BENE_711AE4C6A2',
#    'hcc_code': 'HCC85',
#    'coherence_score': 0.127,
#    'is_fraudulent': True,
#    'fraud_type': 'coding_lag'},
#   {'beneficiary_id': 'BENE_B1CE3C1C2C',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.79,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_9B8BCDA0D4',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.216,
#    'is_fraudulent': True,
#    'fraud_type': 'upcoding'},
#   {'beneficiary_id': 'BENE_1376655482',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.846,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_1376655482',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.937,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_1376655482',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.849,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_CB4B6EC635',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.802,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_01171EA2D5',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.858,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_8BF3F38BB5',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.903,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_045EBE4833',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.775,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_045EBE4833',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.739,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_045EBE4833',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.867,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_045EBE4833',
#    'hcc_code': 'HCC85',
#    'coherence_score': 0.907,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_908CB920F1',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.813,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_908CB920F1',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.747,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_FD0E5B1220',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.742,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_FD0E5B1220',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.954,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_F55533BC5D',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.707,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_09F85F6AB6',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.878,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_3572C2596C',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.711,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_3572C2596C',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.909,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_3572C2596C',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.888,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_3572C2596C',
#    'hcc_code': 'HCC85',
#    'coherence_score': 0.769,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_E670E53C02',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.837,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_E670E53C02',
#    'hcc_code': 'HCC18',
#    'coherence_score': 0.712,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_E670E53C02',
#    'hcc_code': 'HCC85',
#    'coherence_score': 0.936,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_B64BA67223',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.954,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_B97E510DDB',
#    'hcc_code': 'HCC19',
#    'coherence_score': 0.983,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   {'beneficiary_id': 'BENE_62AA5EC671',
#    'hcc_code': 'HCC111',
#    'coherence_score': 0.824,
#    'is_fraudulent': False,
#    'fraud_type': ''},
#   ...]}

# %%
# 2) Build knowledge graph + score coherence (rule-based)
kg = ClinicalKnowledgeGraphLite(hcc_definitions={k: v.__dict__ for k, v in HCC_DEFINITIONS_LITE.items()})
weights_path = os.path.join(PROJECT_ROOT, "mccv", "configs", "hcc_weights.yaml")

scorer = RuleBasedCoherenceScorerLite(
    knowledge_graph=kg,
    weights_config_path=weights_path,
    measurement_start_date=meta.get("measurement_start_date"),
    measurement_end_date=meta.get("measurement_end_date"),
)

preds = scorer.score_dataset(data)  # list[dict]
labels = data["labels"]
label_by_key = {(l["beneficiary_id"], l["hcc_code"]): l for l in labels}

# Merge predictions with ground truth labels
joined = []
for p in preds:
    l = label_by_key.get((p["beneficiary_id"], p["hcc_code"]), {})
    joined.append({**p, **{"is_fraudulent": l.get("is_fraudulent", False), "fraud_type": l.get("fraud_type", "")}})

# Summary stats
fraud_scores = [r["coherence_score"] for r in joined if r["is_fraudulent"]]
legit_scores = [r["coherence_score"] for r in joined if not r["is_fraudulent"]]
print("Scored rows:", len(joined))
print("Mean coherence (fraud):", round(mean(fraud_scores), 3) if fraud_scores else None)
print("Mean coherence (non-fraud):", round(mean(legit_scores), 3) if legit_scores else None)

# Breakdown of high-risk flags by ground-truth fraud_type
high_risk = [r for r in joined if r["coherence_score"] < scorer.high_risk_threshold]
counts = {}
for r in high_risk:
    if not r["is_fraudulent"]:
        continue
    ft = r.get("fraud_type") or "unknown"
    counts[ft] = counts.get(ft, 0) + 1

print(f"High-risk (score < {scorer.high_risk_threshold:.2f}):", len(high_risk), "/", len(joined))
if counts:
    print("High-risk fraud breakdown:")
    for k in sorted(counts.keys()):
        print(f"  - {k}: {counts[k]}")
# Out:
# Scored rows: 8707
# Mean coherence (fraud): 0.184
# Mean coherence (non-fraud): 0.768
# High-risk (score < 0.30): 1070 / 8707
# High-risk fraud breakdown:
#   - coding_lag: 226
#   - hra_only: 96
#   - paper_diagnosis: 533
#   - upcoding: 215

# %%
# 3) Better case presentation (audit-style)

def fmt_pct(x):
    return f"{x:.2f}"

def weights_for(hcc_code: str):
    return scorer.get_weights_for_report(hcc_code)

def contribs(row):
    w = weights_for(row["hcc_code"])
    return {
        "med": w["medication"] * row["pharmacy_score"],
        "lab": w["lab"] * row["lab_score"],
        "spec": w["specialist"] * row["specialist_score"],
        "proc": w["procedure"] * row["procedure_score"],
    }

def dx_record(beneficiary_id: str, hcc_code: str):
    for r in data["diagnosis_records"]:
        if r["beneficiary_id"] == beneficiary_id and r["hcc_code"] == hcc_code:
            return r
    return None

def as_table(rows, limit=10):
    cols = [
        "beneficiary_id",
        "hcc_code",
        "fraud_type",
        "score",
        "source_type",
        "dx_date",
        "wMed*ph",
        "wLab*lab",
        "wSpec*spec",
        "wProc*proc",
    ]

    out = []
    for r in rows[:limit]:
        dx = dx_record(r["beneficiary_id"], r["hcc_code"]) or {}
        c = contribs(r)
        out.append(
            {
                "beneficiary_id": r["beneficiary_id"],
                "hcc_code": r["hcc_code"],
                "fraud_type": r.get("fraud_type") or "",
                "score": fmt_pct(r["coherence_score"]),
                "source_type": dx.get("source_type", ""),
                "dx_date": dx.get("diagnosis_date", ""),
                "wMed*ph": fmt_pct(c["med"]),
                "wLab*lab": fmt_pct(c["lab"]),
                "wSpec*spec": fmt_pct(c["spec"]),
                "wProc*proc": fmt_pct(c["proc"]),
            }
        )

    # simple fixed-width table (no pandas)
    widths = {k: max(len(k), max((len(str(r.get(k, ""))) for r in out), default=0)) for k in cols}
    header = " | ".join(k.ljust(widths[k]) for k in cols)
    sep = "-+-".join("-" * widths[k] for k in cols)
    lines = [header, sep]
    for r in out:
        lines.append(" | ".join(str(r.get(k, "")).ljust(widths[k]) for k in cols))
    return "\n".join(lines)

# pick representative fraud cases: 2 per fraud_type, lowest coherence
fraud_cases = [r for r in joined if r["is_fraudulent"]]
fraud_cases.sort(key=lambda x: x["coherence_score"])

by_type = {}
for r in fraud_cases:
    ft = r.get("fraud_type") or "unknown"
    by_type.setdefault(ft, [])
    if len(by_type[ft]) < 2:
        by_type[ft].append(r)

picked_fraud = []
for ft in sorted(by_type.keys()):
    picked_fraud.extend(by_type[ft])

# pick coherent non-fraud: highest coherence
legit_cases = [r for r in joined if not r["is_fraudulent"]]
legit_cases.sort(key=lambda x: x["coherence_score"], reverse=True)
picked_legit = legit_cases[:10]

print("\nFraud cases (representative; lowest coherence per fraud_type):")
print(as_table(picked_fraud, limit=50))

print("\nNon-fraud cases (highest coherence):")
print(as_table(picked_legit, limit=10))
# Out:
# Fraud cases (representative; lowest coherence per fraud_type):
# beneficiary_id  | hcc_code | fraud_type      | score | source_type | dx_date    | wMed*ph | wLab*lab | wSpec*spec | wProc*proc
# ----------------+----------+-----------------+-------+-------------+------------+---------+----------+------------+-----------
# BENE_95F1F114CF | HCC111   | coding_lag      | 0.00  | EDS         | 2019-09-18 | 0.00    | 0.00     | 0.00       | 0.00
# BENE_95F1F114CF | HCC19    | coding_lag      | 0.00  | Encounter   | 2020-08-05 | 0.00    | 0.00     | 0.00       | 0.00
# BENE_52FB83FD1B | HCC85    | hra_only        | 0.07  | HRA         | 2024-10-04 | 0.04    | 0.04     | 0.00       | 0.00
# BENE_7B7F42361E | HCC18    | hra_only        | 0.08  | HRA         | 2023-03-12 | 0.04    | 0.04     | 0.00       | 0.00
# BENE_A29159334E | HCC111   | paper_diagnosis | 0.00  | EDS         | 2024-09-18 | 0.00    | 0.00     | 0.00       | 0.00
# BENE_A29159334E | HCC18    | paper_diagnosis | 0.00  | EDS         | 2023-02-02 | 0.00    | 0.00     | 0.00       | 0.00
# BENE_F7324FE7FB | HCC18    | upcoding        | 0.22  | Encounter   | 2024-02-04 | 0.04    | 0.09     | 0.05       | 0.04
# BENE_05EDD1FB83 | HCC18    | upcoding        | 0.22  | EDS         | 2024-06-25 | 0.04    | 0.09     | 0.05       | 0.04
#
# Non-fraud cases (highest coherence):
# beneficiary_id  | hcc_code | fraud_type | score | source_type | dx_date    | wMed*ph | wLab*lab | wSpec*spec | wProc*proc
# ----------------+----------+------------+-------+-------------+------------+---------+----------+------------+-----------
# BENE_EA41C65C2E | HCC85    |            | 1.00  | Encounter   | 2023-10-26 | 0.27    | 0.26     | 0.23       | 0.24
# BENE_3093163A0B | HCC19    |            | 1.00  | EDS         | 2023-09-11 | 0.33    | 0.35     | 0.15       | 0.18
# BENE_36AB1A1FBA | HCC19    |            | 1.00  | EDS         | 2024-04-10 | 0.33    | 0.35     | 0.15       | 0.18
# BENE_FEC74E8EC2 | HCC19    |            | 1.00  | EDS         | 2024-05-03 | 0.33    | 0.35     | 0.15       | 0.18
# BENE_C5041C9078 | HCC19    |            | 1.00  | EDS         | 2023-10-16 | 0.33    | 0.35     | 0.15       | 0.18
# BENE_CE65582C68 | HCC111   |            | 1.00  | Encounter   | 2024-10-27 | 0.29    | 0.22     | 0.23       | 0.26
# BENE_85D1A62059 | HCC19    |            | 1.00  | EDS         | 2023-12-10 | 0.33    | 0.35     | 0.15       | 0.18
# BENE_CABBD73B20 | HCC19    |            | 1.00  | Encounter   | 2023-10-29 | 0.33    | 0.35     | 0.15       | 0.18
# BENE_FB539ABC6E | HCC111   |            | 1.00  | Encounter   | 2024-12-01 | 0.29    | 0.22     | 0.23       | 0.26
# BENE_94235BBCA6 | HCC19    |            | 1.00  | Encounter   | 2024-09-04 | 0.33    | 0.35     | 0.15       | 0.18

# %%
# 4) Full explainability report for one selected case

# build one combined claims list
all_claims = []
for k in ["pharmacy_claims", "lab_claims", "specialist_visits", "procedure_claims"]:
    all_claims.extend(data.get(k, []))

# Choose a case to explain: prefer a coding_lag/paper_diagnosis example if present
case_to_explain = None
for ft in ["coding_lag", "paper_diagnosis", "hra_only", "upcoding"]:
    for r in picked_fraud:
        if r.get("fraud_type") == ft:
            case_to_explain = r
            break
    if case_to_explain:
        break

if case_to_explain:
    dx = dx_record(case_to_explain["beneficiary_id"], case_to_explain["hcc_code"]) or {}

    report_gen = AuditReportGeneratorLite(kg)
    weights_for_report = scorer.get_weights_for_report(case_to_explain["hcc_code"])

    report = report_gen.generate_report(
        beneficiary_id=case_to_explain["beneficiary_id"],
        hcc_code=case_to_explain["hcc_code"],
        coherence_score=case_to_explain["coherence_score"],
        all_claims=all_claims,
        diagnosis_origin={
            "source": dx.get("source_type", "Unknown"),
            "date": dx.get("diagnosis_date", "Unknown"),
            "provider": dx.get("provider_npi", "Unknown"),
            "claim_id": dx.get("claim_id", ""),
        },
        weights=weights_for_report,
        measurement_start_date=meta.get("measurement_start_date"),
        measurement_end_date=meta.get("measurement_end_date"),
    )

    print(report_gen.format_report(report))
else:
    print("No fraud cases found to explain (try increasing fraud_rate).")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 24
#      21     report_gen = AuditReportGeneratorLite(kg)
#      22     weights_for_report = scorer.get_weights_for_report(case_to_explain["hcc_code"])
# ---> 24     report = report_gen.generate_report(
#      25         beneficiary_id=case_to_explain["beneficiary_id"],
#      26         hcc_code=case_to_explain["hcc_code"],
#      27         coherence_score=case_to_explain["coherence_score"],
#      28         all_claims=all_claims,
#      29         diagnosis_origin={
#      30             "source": dx.get("source_type", "Unknown"),
#      31             "date": dx.get("diagnosis_date", "Unknown"),
#      32             "provider": dx.get("provider_npi", "Unknown"),
#      33             "claim_id": dx.get("claim_id", ""),
#      34         },
#      35         weights=weights_for_report,
#      36         measurement_start_date=meta.get("measurement_start_date"),
#      37         measurement_end_date=meta.get("measurement_end_date"),
#      38     )
#      40     print(report_gen.format_report(report))
#      41 else:
#
# TypeError: AuditReportGeneratorLite.generate_report() got an unexpected keyword argument 'measurement_start_date'
